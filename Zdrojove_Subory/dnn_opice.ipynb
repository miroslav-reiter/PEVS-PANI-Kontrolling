# %% [markdown]
# # Definícia datasetu Opice (10 Monkey Species)

# %% [markdown]
# ## Čo obsahuje dataset?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

df_dataset_opice = pd.read_csv("monkey_labels.txt", delimiter = ",")
df_dataset_opice
# Out:
#    Label     Latin Name              Common Name                     \
# 0  n0         alouatta_palliata\t    mantled_howler
# 1  n1        erythrocebus_patas\t    patas_monkey
# 2  n2        cacajao_calvus\t        bald_uakari
# 3  n3        macaca_fuscata\t        japanese_macaque
# 4  n4       cebuella_pygmea\t        pygmy_marmoset
# 5  n5       cebus_capucinus\t        white_headed_capuchin
# 6  n6       mico_argentatus\t        silvery_marmoset
# 7  n7      saimiri_sciureus\t        common_squirrel_monkey
# 8  n8       aotus_nigriceps\t        black_headed_night_monkey
# 9  n9       trachypithecus_johnii    nilgiri_langur
#
#     Train Images    Validation Images
# 0             131                  26
# 1             139                  28
# 2             137                  27
# 3             152                  30
# 4             131                  26
# 5             141                  28
# 6             132                  26
# 7             142                  28
# 8             133                  27
# 9             132                  26

# %%
df_dataset_opice.columns = ["Label", "Latin_Name", "Common_Name","Train_Images","Validation_Images"]
df_dataset_opice.head(10)
# Out:
#    Label                Latin_Name                      Common_Name  \
# 0  n0         alouatta_palliata\t    mantled_howler
# 1  n1        erythrocebus_patas\t    patas_monkey
# 2  n2        cacajao_calvus\t        bald_uakari
# 3  n3        macaca_fuscata\t        japanese_macaque
# 4  n4       cebuella_pygmea\t        pygmy_marmoset
# 5  n5       cebus_capucinus\t        white_headed_capuchin
# 6  n6       mico_argentatus\t        silvery_marmoset
# 7  n7      saimiri_sciureus\t        common_squirrel_monkey
# 8  n8       aotus_nigriceps\t        black_headed_night_monkey
# 9  n9       trachypithecus_johnii    nilgiri_langur
#
#    Train_Images  Validation_Images
# 0           131                 26
# 1           139                 28
# 2           137                 27
# 3           152                 30
# 4           131                 26
# 5           141                 28
# 6           132                 26
# 7           142                 28
# 8           133                 27
# 9           132                 26

# %% [markdown]
# ## Deskriptívna štatistika nad datasetom Opice

# %%
df_dataset_opice.describe()
# Out:
#        Train_Images  Validation_Images
# count     10.000000          10.000000
# mean     137.000000          27.200000
# std        6.733003           1.316561
# min      131.000000          26.000000
# 25%      132.000000          26.000000
# 50%      135.000000          27.000000
# 75%      140.500000          28.000000
# max      152.000000          30.000000

# %%
df_dataset_opice.describe(include="all")
# Out:
#         Label             Latin_Name                      Common_Name  \
# count      10                     10                               10
# unique     10                     10                               10
# top     n0      alouatta_palliata\t    mantled_howler
# freq        1                      1                                1
# mean      NaN                    NaN                              NaN
# std       NaN                    NaN                              NaN
# min       NaN                    NaN                              NaN
# 25%       NaN                    NaN                              NaN
# 50%       NaN                    NaN                              NaN
# 75%       NaN                    NaN                              NaN
# max       NaN                    NaN                              NaN
#
#         Train_Images  Validation_Images
# count      10.000000          10.000000
# unique           NaN                NaN
# top              NaN                NaN
# freq             NaN                NaN
# mean      137.000000          27.200000
# std         6.733003           1.316561
# min       131.000000          26.000000
# 25%       132.000000          26.000000
# 50%       135.000000          27.000000
# 75%       140.500000          28.000000
# max       152.000000          30.000000

# %% [markdown]
# ## Aké je rozdelenie datasetu na jednotlivé subsety?

# %%
graf1 = px.pie(
    names = df_dataset_opice["Common_Name"],
    values = df_dataset_opice["Train_Images"],
    width = 650,
    hole = 0.5
)
graf1.update_layout({"title":{"text":"Graf rozdelenia Datasetu na jednotlivé Subsety","x":0.5}})
graf1.show()
# Out:
# <div>                            <div id="ca2bff49-babc-4826-ac29-9654153394cb" class="plotly-graph-div" style="height:525px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca2bff49-babc-4826-ac29-9654153394cb")) {                    Plotly.newPlot(                        "ca2bff49-babc-4826-ac29-9654153394cb",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":[" mantled_howler                "," patas_monkey                  "," bald_uakari                   "," japanese_macaque              "," pygmy_marmoset                "," white_headed_capuchin         "," silvery_marmoset              "," common_squirrel_monkey        "," black_headed_night_monkey     "," nilgiri_langur                "],"legendgroup":"","name":"","showlegend":true,"values":[131,139,137,152,131,141,132,142,133,132],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF ...

# %%
from matplotlib.pyplot import figure
#figure(figsize=(10, 6), dpi=80)
plt.rcParams["figure.figsize"] = (20,5)

plot = plt.pie(df_dataset_opice["Train_Images"], labels = df_dataset_opice["Common_Name"], autopct="%1.2f%%")
#plt.legend(title = "Common_Name:", loc="center right")
plt.title("Graf rozdelenia Datasetu na jednotlivé Subsety")
plt.show()

# %% [markdown]
# ## Aké kategórie predikujeme?

# %% [markdown]
# kategorie_nazvy = list(df_dataset_opice['Common_Name'])
# labels = list(df_dataset_opice['Label'])
# print(f"Pocet kategorii: {len(kategorie_nazvy)}")
# kategorie_nazvy

# %% [markdown]
# ## Načítanie Obrázkov

# %%
import os

def load_images(path):
    ''' Put files into lists and return them as one list with all images
     in the folder'''
    image_files = sorted([os.path.join(path, file)
                          for file in os.listdir(path)
                          if file.endswith(".jpeg") or file.endswith(".jpg") or file.endswith(".png")])
    return image_files

n0_obrazky = load_images("data/train/n0")
n1_obrazky = load_images("data/train/n1")
n2_obrazky = load_images("data/train/n2")
n3_obrazky = load_images("data/train/n3")
n4_obrazky = load_images("data/train/n4")
n5_obrazky = load_images("data/train/n5")
n6_obrazky = load_images("data/train/n6")
n7_obrazky = load_images("data/train/n7")
n8_obrazky = load_images("data/train/n8")
n9_obrazky = load_images("data/train/n9")

img=plt.imread(n0_obrazky[0])
print(f"Rozmer obrazka ({n0_obrazky[0]}) je: {img.shape} px")

plt.title(n0_obrazky[0])
plt.imshow(plt.imread(n0_obrazky[0]))
plt.show()
# Out:
# Rozmer obrazka (data/train/n0\n0018.jpg) je: (367, 550, 3) px

# %% [markdown]
# ### Dáta z každého druhu opice

# %%
from PIL import Image
from tensorflow.keras.preprocessing.image import load_img

obrazky_priklady = ["data/train/n0/",
"data/train/n1/",
"data/train/n2/",
"data/train/n3/",
"data/train/n4/",
"data/train/n5/",
"data/train/n6/",
"data/train/n7/",
"data/train/n8/",
"data/train/n9/"]

fig = plt.figure(figsize = (20, 10))

print("Dáta/obrázky z každého druhu opice")
j = 1
for i in obrazky_priklady:
    filenames  = os.listdir(i)
    priklad = filenames[0]
    img = load_img(i + priklad)

    plt.subplot(2, 5, j)
    plt.axis('equal') #off
    plt.imshow(img)
    plt.xlabel(f"Druh opíc: n{j - 1}")
    j += 1

plt.show()
# Out:
# Dáta/obrázky z každého druhu opice

# %% [markdown]
# ## Klasifikácia obrázkov, využitie ImageDataGeneratora z TensorFlow

# %%
# Prevzaté z Kaggle (https://www.kaggle.com/code/gaber0512/monkey-species-convolutional-neural-network) a
# TensorFlow (https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
from pathlib import Path

train = Path('data/train/')
test = Path('data/validation/')

train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
        train,
        target_size = (64, 64),
        batch_size = 32,
        class_mode = 'categorical')
validation_generator = test_datagen.flow_from_directory(
        test,
        target_size = (64, 64),
        batch_size = 32,
        class_mode = 'categorical')
# Out:
# Found 1098 images belonging to 10 classes.
# Found 272 images belonging to 10 classes.

# %%
train = Path('data/train/')
test = Path('data/validation/')

train_filepaths = list(train.glob(r'**/*.jpg'))
test_filepaths = list(test.glob(r'**/*.jpg'))

# %% [markdown]
# ## Štruktúra modelu

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPool2D,Flatten,Dropout

model = Sequential()
model.add(Conv2D(filters=32,kernel_size=(3,3),input_shape=(64,64,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=32,kernel_size=(3,3),input_shape=(64,64,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(150,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer ='adam', metrics= ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 150)               940950
#
#  dense_1 (Dense)             (None, 10)                1510
#
# =================================================================
# Total params: 952,604
# Trainable params: 952,604
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',patience=4)

# %% [markdown]
# ## Model Fit

# %%
model.fit_generator(train_generator, epochs = 20 ,validation_data=validation_generator,callbacks=early_stop,verbose = 1)
# Out:
# C:\Users\miros\AppData\Local\Temp\ipykernel_28228\1432497678.py:1: UserWarning:
#
# `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/20
# 35/35 [==============================] - 42s 1s/step - loss: 2.1534 - accuracy: 0.2040 - val_loss: 1.8411 - val_accuracy: 0.3162
# Epoch 2/20
# 35/35 [==============================] - 38s 1s/step - loss: 1.7162 - accuracy: 0.3907 - val_loss: 1.5907 - val_accuracy: 0.4118
# Epoch 3/20
# 35/35 [==============================] - 38s 1s/step - loss: 1.4124 - accuracy: 0.5228 - val_loss: 1.4641 - val_accuracy: 0.5074
# Epoch 4/20
# 35/35 [==============================] - 36s 1s/step - loss: 1.2647 - accuracy: 0.5683 - val_loss: 1.2718 - val_accuracy: 0.5772
# Epoch 5/20
# 35/35 [==============================] - 37s 1s/step - loss: 1.1470 - accuracy: 0.6075 - val_loss: 1.2222 - val_accuracy: 0.5882
# Epoch 6/20
# 35/35 [==============================] - 37s 1s/step - loss: 1.0661 - accuracy: 0.6366 - val_loss: 1.2333 - val_accuracy: 0.5993
# Epoch 7/20
# 35/35 [==============================] - 36s 1s/step - loss: 0.9508 - accuracy: 0.6785 - val_loss: 1.0997 - val_accuracy: 0.6140
# Epoch 8/20
# 35/35 [==============================] - 36s 1s/step - loss: 0.9448 - accuracy: 0.6840 - val_loss: 1.0910 - val_accuracy: 0.6250
# Epoch 9/20
# 35/35 [==============================] - 35s 1s/step - loss: 0.8135 - accuracy: 0.7395 - val_loss: 1.0656 - val_accuracy: 0.6213
# Epoch 10/20
# 35/35 [==============================] - 36s 1s/step - loss: 0.7821 - accuracy: 0.7304 - val_loss: 1.1339 - val_accuracy: 0.6213
# Epoch 11/20
# 35/35 [==============================] - 33s 953ms/step - loss: 0.7311 - accuracy: 0.7514 - val_loss: 1.1838 - val_accuracy: 0.5882
# Epoch 12/20
# 35/35 [==============================] - 33s 948ms/step - loss: 0.7412 - accuracy: 0.7505 - val_loss: 0.9865 - val_accuracy: 0.6875
# Epoch 13/20
# 35/35 [==============================] - 34s 975ms/step - loss: 0.6272 - accuracy: 0.7814 - val_loss: 0.9644 - val_accuracy: 0.6728
# Epoch 14/20
# 35/35 [==============================] - 36s 1s/step - loss: 0.5975 - accuracy: 0.7996 - val_loss: 1.0678 - val_accuracy: 0.6838
# Epoch 15/20
# 35/35 [==============================] - 35s 1s/step - loss: 0.5402 - accuracy: 0.8297 - val_loss: 1.3942 - val_accuracy: 0.5956
# Epoch 16/20
# 35/35 [==============================] - 46s 1s/step - loss: 0.4958 - accuracy: 0.8288 - val_loss: 1.0982 - val_accuracy: 0.6765
# Epoch 17/20
# 35/35 [==============================] - 42s 1s/step - loss: 0.4100 - accuracy: 0.8734 - val_loss: 1.2141 - val_accuracy: 0.6066

# %%
loses = pd.DataFrame(model.history.history)
loses.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  2.153351  0.204007  1.841100      0.316176
# 1  1.716243  0.390710  1.590735      0.411765
# 2  1.412423  0.522769  1.464079      0.507353
# 3  1.264746  0.568306  1.271787      0.577206
# 4  1.147000  0.607468  1.222212      0.588235

# %%
loses[['accuracy','val_accuracy']].plot()
# Out:
# <AxesSubplot: >

# %%
loses[['loss','val_loss']].plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Predikcia modelu
